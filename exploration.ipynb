# %% [markdown]
# ## Coloring Problem

# %%
# !clingo examples/color/color.lp --outf=2 | clingraph --out=render --view --dir='out/color' --format=png --select-model=0 -log=info
# Out:
# -> Image for graph default, saved in: out/color/0/default.png

# %%
from IPython.display import Image
Image("./out/color/0/default.png")

# %% [markdown]
# ## Queens Problem

# %%
# !clingo examples/queens/encoding.lp -c n=5 --outf=2 | clingraph --viz-encoding=examples/queens/viz.lp --dir='out/queens' --out=dot --engine=neato
# Out:
# graph default {
# 	"(3,5)" [label="♕" fillcolor=gray fontsize=50 pos="3,5!" shape=square style=filled width=1]
# 	"(2,5)" [fillcolor=white pos="2,5!" shape=square style=filled width=1]
# 	"(2,4)" [fillcolor=gray pos="2,4!" shape=square style=filled width=1]
# 	"(1,3)" [fillcolor=gray pos="1,3!" shape=square style=filled width=1]
# 	"(3,3)" [fillcolor=gray pos="3,3!" shape=square style=filled width=1]
# 	"(1,2)" [fillcolor=white pos="1,2!" shape=square style=filled width=1]
# 	"(4,1)" [fillcolor=white pos="4,1!" shape=square style=filled width=1]
# 	"(5,3)" [fillcolor=gray pos="5,3!" shape=square style=filled width=1]
# 	"(2,3)" [fillcolor=white pos="2,3!" shape=square style=filled width=1]
# 	"(2,1)" [fillcolor=white pos="2,1!" shape=square style=filled width=1]
# 	"(4,5)" [fillcolor=white pos="4,5!" shape=square style=filled width=1]
# 	"(3,4)" [fillcolor=white pos="3,4!" shape=square style=filled width=1]
# ...

# %% [markdown]
# ## Elevator Problem

# %%
# !clingo examples/elevator/{encoding,instance}.lp --outf=2 | clingraph --viz-encoding=examples/elevator/viz.lp --out=animate --select-model=0 --fps=1 --sort=asc-int
# Out:
# -> Gif for graph all, saved in: out/0/movie.gif

# %%
from IPython.display import Image
Image("./out/0/movie.gif")
